# %%
import pandas as pd
import json

# %%
# Read json
data = json.load(open("test_data.json"))
df_full = pd.json_normalize(data["jobs_results"])
df_full.head(100)
# Out:
#                                          title                  company_name  \
# 0       Data Scientist, Crypto Investment Firm       Recruiting from Scratch
# 1            Informatics Data Science Engineer    Florida Cancer Specialists
# 2                        Senior Data Scientist       Chubb INA Holdings Inc.
# 3  Data Scientist – US Commercial Data Science  Bristol Myers Squibb Careers
# 4                               Data Scientist                         Merck
# 5                               Data Scientist  Fidelity Investments Careers
# 6                     Principal Data Scientist                     Overstory
# 7                    Data Scientist, Lead Jobs           Booz Allen Hamilton
# 8            Data Scientist (Forecasting) (US)               Tiger Analytics
# 9                     Sr. Data Scientist (NLP)                      MCKESSON
#
#                          location  \
# 0               Plymouth, WA, USA
# 1                  Tampa, FL, USA
# ...
