# %%
from serpapi import GoogleSearch

# %%
params = {
    "engine": "google_jobs",
    "q": "data scientist",
    "hl": "en",
    "api_key": "a50a83b24d1e51c42d6567fb1bd517dadd4d4348957fe3450928060bbb400ada",
    "gl": "uk"
}

search = GoogleSearch(params)
results = search.get_dict()
jobs_results = results["jobs_results"]
# Out:
# https://serpapi.com/search

# %%
from pprint import pprint

# %%
pprint(results)
# Out:
# {'chips': [{'options': [{'text': 'All'},
#                         {'text': 'Data scientist', 'value': 'data scientist'},
#                         {'text': 'Data science', 'value': 'data science'},
#                         {'text': 'Manager', 'value': 'manager'},
#                         {'text': 'Director', 'value': 'director'},
#                         {'text': 'Consultant', 'value': 'consultant'},
#                         {'text': 'Engineer', 'value': 'engineer'},
#                         {'text': 'Principal', 'value': 'principal'},
#                         {'text': 'Analyst', 'value': 'analyst'},
#                         {'text': 'Analytics consultant',
#                          'value': 'analytics consultant'},
#                         {'text': 'Application engineer',
#                          'value': 'application engineer'},
#                         {'text': 'Applied scientist',
#                          'value': 'applied scientist'},
#                         {'text': 'Associate', 'value': 'associate'},
#                         {'text': 'Associate director',
#                          'value': 'associate director'},
#                         {'text': 'Data engineer', 'value': 'data engineer'},
#                         {'text': 'Design engineer', 'value': 'design engineer'},
#                         {'text': 'Principal scientist',
#                          'value': 'principal scientist'},
#                         {'text': 'Program manager', 'value': 'program manager'},
#                         {'text': 'Researcher', 'value': 'researcher'},
#                         {'text': 'Senior', 'value': 'senior'},
#                         {'text': 'Senior manager', 'value': 'senior manager'},
#                         {'text': 'Software engineer',
#                          'value': 'software engineer'},
#                         {'text': 'Specialist', 'value': 'specialist'},
#                         {'text': 'University', 'value': 'university'}],
#             'param': 'job_family_1',
#             'type': 'Title'},
#            {'options': [{'text': 'All'},
#                         {'text': 'New York, NY',
#                          'value': 'Owg_06VPwoli_nfhBo8LyA=='},
#                         {'text': 'Washington, DC',
#                          'value': 'W-T2Wt7Gt4kqXYjUIkVSwg=='},
#                         {'text': 'Boston, MA',
#                          'value': 'GzE9DS1l44mg6GIBJL98eA=='},
#                         {'text': 'San Francisco, CA',
#                          'value': 'IQBpAG2ahYD_rXbwZxNQSg=='},
#                         {'text': 'Seattle, WA',
#                          'value': 'VTPokywQkFSa1URpRmUlEA=='},
#                         {'text': 'Austin, TX',
#                          'value': 'LwPMoJm1RIZ61WnUS0abXQ=='},
#                         {'text': 'McLean, VA',
#                          'value': 'O3mKsew1tonx6vqtXrpijg=='},
#                         {'text': 'Chicago, IL',
#                          'value': '7cv00DwsDogAwMAJrabgrw=='},
#                         {'text': 'Herndon, VA',
#                          'value': 'Q6ZdDwY4tol9NWwctSKAkg=='},
#                         {'text': 'Las Vegas, NV',
#                          'value': '0X31pIK3voCjebPV5tXMOg=='},
#                         {'text': 'Mountain View, CA',
#                          'value': 'iQHsW0m3j4Cbr2tGStQXfA=='},
#                         {'text': 'Pittsburgh, PA',
#                          'value': 'A4UGSG_xNIg0G6JaoRX5jQ=='},
#                         {'text': 'Annapolis Junction, MD',
#                          'value': 'zW-xYyLnt4mqAms5YL-SKQ=='},
#                         {'text': 'Atlanta, GA',
#                          'value': 'jQmTaV0E9YgLYwuZL97-Zg=='},
#                         {'text': 'Bellevue, WA',
#                          'value': 'QWCmo89rkFRlB9DqglTPug=='},
#                         {'text': 'Cambridge, MA',
#                          'value': 'X8wwy6Vw44mHbGiJZI46xQ=='},
#                         {'text': 'Chantilly, VA',
#                          'value': 'GXJnGVZBtomDrRZD_PBBQA=='},
#                         {'text': 'Dallas, TX',
#                          'value': 'S5dFe_cZTIaPZ0f2pJvsuQ=='},
#                         {'text': 'Honolulu, HI',
#                          'value': 'TUbDjDsYAHxsl6fzX_UoSw=='},
#                         {'text': 'Minneapolis, MN',
#                          'value': 'vbt3k5Azs1IH7novhMmfkw=='},
#                         {'text': 'Norfolk, VA',
#                          'value': 'RcoiUzqXuokKHnrOfxCZqw=='},
#                         {'text': 'San Jose, CA',
#                          'value': '9T_5iuTKj4B7cZ_KCoyduQ=='},
#                         {'text': 'St. Louis, MO',
#                          'value': '-Y7t-qm02Idb4Lsiyuo5vg=='},
#                         {'text': 'Arlington, VA',
#                          'value': 'D6ene522t4mTsPZFyG_P-A=='},
#                         {'text': 'Charlotte, NC',
#                          'value': 'gRo4_MQfVIhk0UO_5lBGiA=='},
#                         {'text': 'Columbia, MD',
#                          'value': 'UaBpY7Dft4ldY4e2Zb3W8A=='},
#                         {'text': 'Denver, CO',
#                          'value': 'zxcfI6qAa4fWNoon-PSOEQ=='},
#                         {'text': 'Des Moines, IA',
#                          'value': '5x5hwaSZ7oey5JEmUSgAcQ=='},
#                         {'text': 'Fairfax, VA',
#                          'value': 'zZFLOZZOtolAhkSF5yYjBw=='},
#                         {'text': 'Fort Belvoir, VA',
#                          'value': '3-oBRQAAt4mClX1eQIlrxQ=='},
#                         {'text': 'Lexington, MA',
#                          'value': 'y1hS39qd44nNEzYWyIU2hQ=='},
#                         {'text': 'Los Angeles, CA',
#                          'value': 'E9on3F3HwoD0CEYlb98v4g=='},
#                         {'text': 'Miami, FL',
#                          'value': 'EcHIDqKw2YhlT63dcfKW_w=='},
#                         {'text': 'Palo Alto, CA',
#                          'value': 'ORy6nXuwj4DPdvU1UvUfDg=='},
#                         {'text': 'Philadelphia, PA',
#                          'value': '60u11Ni3xonBWD6M2BT1iQ=='},
#                         {'text': 'Redwood City, CA',
#                          'value': '4V7zUzmgj4BtaqoLm3vkuA=='},
#                         {'text': 'Reston, VA',
#                          'value': '5WUWJkdAtomfrnGo6K_fYw=='},
#                         {'text': 'Richmond, VA',
#                          'value': '7cmZVwkRsYnFPELibT7Yvw=='},
#                         {'text': 'San Bruno, CA',
#                          'value': 'OSmpLuR5j4DS72A5yKQd2g=='},
#                         {'text': 'San Mateo, CA',
#                          'value': 'RVWp72Cej4CnG8wt9PyO_Q=='},
#                         {'text': 'Sunnyvale, CA',
#                          'value': 'O13QqUW2j4Ciw3zdJvuNdg=='},
#                         {'text': 'Albany, NY',
#                          'value': 'S_tPzDQK3onEKOegEmOh4Q=='},
#                         {'text': 'Alexandria, VA',
#                          'value': '8aukkz5NtoksAcHbhib11w=='},
#                         {'text': 'Augusta, ME',
#                          'value': 'ncSsr_0AskwtCyJkjUijeQ=='},
#                         {'text': 'Beavercreek, OH',
#                          'value': 'B-LwKg6bQIiC7xPC5lB3ug=='},
#                         {'text': 'Berkeley, CA',
#                          'value': '00mFOjZ5hYCT6XWmlRXqlA=='},
#                         {'text': 'Bethesda, MD',
#                          'value': 'LQIkarfLt4kNzStq93myJg=='},
#                         {'text': 'Boise, ID',
#                          'value': 'nbRH6XLxrlSbnWc2m5hbmg=='},
#                         {'text': 'Boulder, CO',
#                          'value': '06-NJ06Na4dYgBugfDs5yA=='},
#                         {'text': 'Burbank, CA',
#                          'value': 'lcUYKBWVwoDUih-Qr5F3MA=='},
#                         {'text': 'Burke, VA',
#                          'value': 'I-7w5gFStolVEtCeL2FuPA=='},
#                         {'text': 'Burlington, VT',
#                          'value': '5VWbtlV6ykyOSQ5yGeVfww=='},
#                         {'text': 'Carrollton, TX',
#                          'value': 'H1fduyshTIZdHYSzSf0enA=='}],
#             'param': 'city',
#             'type': 'Location'},
#            {'options': [{'text': 'All'},
#                         {'text': 'Past day', 'value': 'today'},
#                         {'text': 'Past 3 days', 'value': '3days'},
#                         {'text': 'Past week', 'value': 'week'},
#                         {'text': 'Past month', 'value': 'month'}],
#             'param': 'date_posted',
#             'type': 'Date posted'},
#            {'options': [{'text': 'All'},
#                         {'text': 'Full–time', 'value': 'FULLTIME'},
#                         {'text': 'Part-time', 'value': 'PARTTIME'},
#                         {'text': 'Contractor', 'value': 'CONTRACTOR'},
#                         {'text': 'Internship', 'value': 'INTERN'}],
#             'param': 'employment_type',
#             'type': 'Type'},
#            {'options': [{'text': 'All'},
#                         {'text': 'Manufacturing',
#                          'value': '/business/naics2007/31'},
#                         {'text': 'Consulting',
#                          'value': '/business/naics2007/5416'},
#                         {'text': 'Finance', 'value': '/business/naics2007/52'},
#                         {'text': 'Information',
#                          'value': '/business/naics2007/51'},
#                         {'text': 'Retail', 'value': '/business/naics2007/44'},
#                         {'text': 'Computer Services',
#                          'value': '/business/naics2007/5415'},
#                         {'text': 'Education',
#                          'value': '/business/naics2007/61'},
#                         {'text': 'Health Care',
#                          'value': '/business/naics2007/62'},
#                         {'text': 'Foods & Beverages',
#                          'value': '/business/naics2007/311'},
#                         {'text': 'Wholesale',
#                          'value': '/business/naics2007/42'},
#                         {'text': 'Construction',
#                          'value': '/business/naics2007/23'},
#                         {'text': 'Professional Services',
#                          'value': '/business/naics2007/5419'},
#                         {'text': 'Research',
#                          'value': '/business/naics2007/5417'},
#                         {'text': 'Utilities',
#                          'value': '/business/naics2007/22'},
#                         {'text': 'Engineering Services',
#                          'value': '/business/naics2007/5413'},
#                         {'text': 'Staffing',
#                          'value': '/business/naics2007/5613'},
#                         {'text': 'Advertising',
#                          'value': '/business/naics2007/5418'},
#                         {'text': 'Design Services',
#                          'value': '/business/naics2007/5414'},
#                         {'text': 'Entertainment',
#                          'value': '/business/naics2007/71'},
#                         {'text': 'Logistics',
#                          'value': '/business/naics2007/48'},
#                         {'text': 'Mining', 'value': '/business/naics2007/21'},
#                         {'text': 'Personal Care',
#                          'value': '/business/naics2007/8121'},
#                         {'text': 'Toiletries',
#                          'value': '/business/naics2007/3256'},
#                         {'text': 'Travel',
#                          'value': '/business/naics2007/5615'}],
#             'param': 'industry.id',
#             'type': 'Company type'},
#            {'options': [{'text': 'All'},
#                         {'text': 'Booz Allen Hamilton', 'value': '/m/05jlg3'},
#                         {'text': 'Guidehouse', 'value': '/m/03p3pyz'},
#                         {'text': 'Merck', 'value': '/m/04f0xq'},
#                         {'text': 'Walmart', 'value': '/m/0841v'},
#                         {'text': 'Perficient', 'value': '/m/0dp9h2'},
#                         {'text': 'Apple', 'value': '/m/0k8z'},
#                         {'text': 'Deloitte', 'value': '/m/02spfd'},
#                         {'text': 'Discover Financial Services',
#                          'value': '/m/02wydsr'},
#                         {'text': 'Amazon', 'value': '/m/0mgkg'},
#                         {'text': 'Cardinal Health', 'value': '/m/040vzx'},
#                         {'text': 'Reddit', 'value': '/m/0bx7cy_'},
#                         {'text': 'S&P Global', 'value': '/m/02_nl4'},
#                         {'text': 'Santander Holdings USA Inc',
#                          'value': '/m/0wsyrp9'},
#                         {'text': 'Bristol-Myers Squibb', 'value': '/m/02hh10'},
#                         {'text': 'CVS Health', 'value': '/m/02q9wld'},
#                         {'text': 'Diverse Lynx', 'value': '/g/11dxp_49r_'},
#                         {'text': 'Fidelity Investments Careers',
#                          'value': '/m/028q26'},
#                         {'text': 'Gemini', 'value': '/g/11cjcyg_2t'},
#                         {'text': 'General Motors', 'value': '/m/035nm'},
#                         {'text': 'JPMorgan Chase & Co.', 'value': '/m/01hlwv'},
#                         {'text': 'MITRE', 'value': '/m/02bzst'},
#                         {'text': 'ManTech', 'value': '/m/03crmnd'},
#                         {'text': 'Peraton', 'value': '/g/11g9mq8fj6'},
#                         {'text': 'Resume Library', 'value': '/m/0125jjxn'},
#                         {'text': 'Takeda', 'value': '/m/01rm4t'},
#                         {'text': 'Technology Partners',
#                          'value': '/g/11g6__5mtc'},
#                         {'text': 'Tempus Labs, Inc.', 'value': '/g/11g9mk9ftx'},
#                         {'text': 'University of California, Berkeley',
#                          'value': '/m/02zd460'},
#                         {'text': 'Upwork', 'value': '/m/02pzh5d'},
#                         {'text': 'Abbott Laboratories', 'value': '/m/02gkg4'},
#                         {'text': 'Agoda', 'value': '/g/12nvpqwlt'},
#                         {'text': 'Airbnb', 'value': '/m/010qmszp'},
#                         {'text': 'Airswift', 'value': '/g/11clw7gnbh'},
#                         {'text': 'Alpha Theory', 'value': '/g/11dxptgklw'},
#                         {'text': 'American College of Cardiology',
#                          'value': '/m/04wjky'},
#                         {'text': 'Aristocrat', 'value': '/m/067hv8'},
#                         {'text': 'Ascension', 'value': '/g/11jfc272qc'},
#                         {'text': 'AstraZeneca', 'value': '/m/028zbs'},
#                         {'text': 'AutoZone', 'value': '/m/02z6wl'},
#                         {'text': 'BLUE ORIGIN', 'value': '/m/03lwz4'}],
#             'param': 'organization_mid',
#             'type': 'Employer'}],
#  'jobs_results': [{'company_name': 'Recruiting from Scratch',
#                    'description': 'Who is Recruiting from Scratch:\n'
#                                   '\n'
#                                   'Recruiting from Scratch is a premier talent '
#                                   'firm that focuses on placing the best '
#                                   'product managers, software, and hardware '
#                                   'talent at innovative companies. Our team is '
#                                   '100% remote and we work with teams across '
#                                   'the United States to help them hire. We '
#                                   'work with companies funded by the best '
#                                   'investors including Sequoia Capital, '
#                                   'Lightspeed Ventures, Tiger Global... '
#                                   'Management, A16Z, Accel, DFJ, and more.\n'
#                                   '\n'
#                                   'Our Client:\n'
#                                   '\n'
#                                   'Our client is a crypto-focused investment '
#                                   'firm.\n'
#                                   '\n'
#                                   'Our client is seeking a Data Scientist to '
#                                   'join its investments team. The Data '
#                                   'Scientist’s primary responsibility will be '
#                                   'to interpret on-chain data and provide '
#                                   'data-driven insights that power investment '
#                                   'decisions. This will involve owning all '
#                                   'parts of our data science tech stack:\n'
#                                   '• Working closely with our engineering team '
#                                   'to build efficient ETL pipelines\n'
#                                   '• Building tools and frameworks to provide '
#                                   'scalable data-driven insights\n'
#                                   '• Producing data-driven reports to '
#                                   'supplement investment decisions\n'
#                                   '\n'
#                                   'The essence of the role is to live at the '
#                                   'bleeding edge of interpreting on-chain '
#                                   'crypto data. For the first time in history, '
#                                   'all of the data related to a growing '
#                                   'digital economy is open source and '
#                                   'available to anyone. However, this data is '
#                                   'messy and underexplored. In this role, you '
#                                   'will be responsible for spearheading our '
#                                   'exploration and analysis of on-chain crypto '
#                                   'data.\n'
#                                   '\n'
#                                   'There will be an emphasis on presenting '
#                                   'analyses and findings in a digestible form '
#                                   'that influence investment decisions. We are '
#                                   'looking for a Data Scientist that can '
#                                   'translate data- driven insights into '
#                                   'concise, well written reports.\n'
#                                   '\n'
#                                   'We work as a cohesive team and expect '
#                                   'everybody at our client to think like an '
#                                   'owner, not an agent. While the first few '
#                                   'months will involve hands-on training, the '
#                                   'Data Scientist must be a self- starter and '
#                                   'independent thinker who can operate with '
#                                   'minimal supervision.\n'
#                                   '\n'
#                                   'Requirements\n'
#                                   '• 1-2 years of product/strategy-oriented '
#                                   'data science work experience\n'
#                                   '• Strong quantitative and statistical '
#                                   'analysis background, including regression, '
#                                   'hypothesis testing, clustering analysis, '
#                                   'and network analysis\n'
#                                   '• Proficiency using SQL, Git, and Python/R, '
#                                   'including standard libraries such as '
#                                   'Pandas, Numpy, and Tidyverse\n'
#                                   '• Proven intuition of translating business '
#                                   'problems to statistical problems\n'
#                                   '• Excellent written communication\n'
#                                   '• Demonstrated interest in crypto. If you '
#                                   'cannot describe what Bitcoin, Ethereum, and '
#                                   'DeFi are, then this role is not a fit. '
#                                   'Ideally, you are completely obsessed with '
#                                   'crypto\n'
#                                   '• Deep curiosity, strong opinions, and '
#                                   'intellectual flexibility. If you do not '
#                                   'hold strong opinions and almost always '
#                                   'agree with the consensus, then this role is '
#                                   'not for you\n'
#                                   '• No unchecked egos. At our client, we all '
#                                   'work towards the collective success of the '
#                                   'firm, and do not aim for individual '
#                                   'recognition. People who care more about '
#                                   'building their personal brands than '
#                                   'contributing to building a world-class team '
#                                   'need not apply.\n'
#                                   '• Must live or be willing to relocate to '
#                                   'NYC. We will be working from the office at '
#                                   'least four days per week.\n'
#                                   '\n'
#                                   'If you do not meet these requirements, '
#                                   'please do not apply. If you believe you do, '
#                                   'please include a very short note / send a '
#                                   'message along with your application '
#                                   'describing your experience and skillset, '
#                                   'with particular attention to your level of '
#                                   'interest in crypto.\n'
#                                   '\n'
#                                   'Starting salary of $150k with above-market '
#                                   'benefits',
#                    'detected_extensions': {'posted_at': '15 hours ago',
#                                            'schedule_type': 'Full–time'},
#                    'extensions': ['15 hours ago', 'Full–time'],
#                    'job_highlights': [{'items': ['1-2 years of '
#                                                  'product/strategy-oriented '
#                                                  'data science work experience',
#                                                  'Strong quantitative and '
#                                                  'statistical analysis '
#                                                  'background, including '
#                                                  'regression, hypothesis '
#                                                  'testing, clustering '
#                                                  'analysis, and network '
#                                                  'analysis',
#                                                  'Proficiency using SQL, Git, '
#                                                  'and Python/R, including '
#                                                  'standard libraries such as '
#                                                  'Pandas, Numpy, and Tidyverse',
#                                                  'Proven intuition of '
#                                                  'translating business '
#                                                  'problems to statistical '
#                                                  'problems',
#                                                  'Excellent written '
#                                                  'communication',
#                                                  'Demonstrated interest in '
#                                                  'crypto',
#                                                  'Ideally, you are completely '
#                                                  'obsessed with crypto',
#                                                  'Deep curiosity, strong '
#                                                  'opinions, and intellectual '
#                                                  'flexibility',
#                                                  'If you do not hold strong '
#                                                  'opinions and almost always '
#                                                  'agree with the consensus, '
#                                                  'then this role is not for '
#                                                  'you',
#                                                  'Must live or be willing to '
#                                                  'relocate to NYC'],
#                                        'title': 'Qualifications'},
#                                       {'items': ['The Data Scientist’s primary '
#                                                  'responsibility will be to '
#                                                  'interpret on-chain data and '
#                                                  'provide data-driven insights '
#                                                  'that power investment '
#                                                  'decisions',
#                                                  'Working closely with our '
#                                                  'engineering team to build '
#                                                  'efficient ETL pipelines',
#                                                  'Building tools and '
#                                                  'frameworks to provide '
#                                                  'scalable data-driven '
#                                                  'insights',
#                                                  'Producing data-driven '
#                                                  'reports to supplement '
#                                                  'investment decisions',
#                                                  'In this role, you will be '
#                                                  'responsible for spearheading '
#                                                  'our exploration and analysis '
#                                                  'of on-chain crypto data',
#                                                  'There will be an emphasis on '
#                                                  'presenting analyses and '
#                                                  'findings in a digestible '
#                                                  'form that influence '
#                                                  'investment decisions'],
#                                        'title': 'Responsibilities'},
#                                       {'items': ['Starting salary of $150k '
#                                                  'with above-market benefits'],
#                                        'title': 'Benefits'}],
#                    'job_id': '...',
#                    'location': 'Plymouth, WA, USA',
#                    'related_links': [{'link': 'https://www.google.com/search?hl=en&gl=uk&q=Recruiting+from+Scratch&sa=X&ved=0ahUKEwicqYjpy7X9AhV7F1kFHYd-ABkQmJACCKUI',
#                                       'text': 'See web results for Recruiting '
#                                               'from Scratch'}],
#                    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQfRxZ8pRuZwPdzMvA-f84DAa-TBCFPeFZgAgbywRg&s',
#                    'title': 'Data Scientist, Crypto Investment Firm',
#                    'via': 'via LinkedIn'},
#                   {'company_name': 'Florida Cancer Specialists',
#                    'description': 'Job Description Summary:\n'
#                                   '\n'
#                                   'Under the direction of the Data Science & '
#                                   'Analytics Manager (DSAM), the Data '
#                                   'Scientist (DSE) will be transformational in '
#                                   'bringing data analytics and Data as a '
#                                   'Service (DaaS) to Florida Cancer '
#                                   'Specialists. The Data Scientist (DSE) '
#                                   'possesses healthcare domain knowledge '
#                                   'combined with statistical data expertise to '
#                                   'develop Florida Cancer Specialists data '
#                                   'platform to further... cancer research. The '
#                                   'Data Scientist works cross functionally '
#                                   "with the 'trusted data' and DaaS teams to "
#                                   'provide guidance as to how best to surface '
#                                   'data science insights with an application.\n'
#                                   '\n'
#                                   'As a Data Scientist (DSE) you will be '
#                                   'engaged in analysis, code development, data '
#                                   'integration and performance optimization '
#                                   'initiatives to provide data science '
#                                   'insights to users. A Data Science Engineer '
#                                   '(DSE) functions in both a consultative and '
#                                   'technical capacity to deliver highly '
#                                   'dimensional data intensive concepts. To '
#                                   'thrive on the FCS Informatics team the Data '
#                                   'Scientist (DSE) must be an active '
#                                   'contributor in a cross-functional '
#                                   'entrepreneurial agile scrum environment to '
#                                   'deliver in demand agile analytics.\n'
#                                   '\n'
#                                   'Demonstrates working knowledge of all '
#                                   'facets of role, relevant regulations, and '
#                                   'organizational and departmental policies '
#                                   'and procedures. Performs other duties and '
#                                   'projects as assigned. Performs all duties '
#                                   'in accordance with regulatory requirements '
#                                   'and organizational policies and '
#                                   'procedures.\n'
#                                   '\n'
#                                   'Position Qualifications/Requirements\n'
#                                   '\n'
#                                   'Education:\n'
#                                   "• Bachelor's degree in business analytics, "
#                                   'computer science, engineering, accounting, '
#                                   'finance, management information systems or '
#                                   'another related field. In lieu of degree, '
#                                   '10+ years of experience is required or the '
#                                   'equivalent combination for education and '
#                                   'experience Certifications/Licenses:\n'
#                                   '• Enter required licensure or N/A\n'
#                                   '• Enter required certification or N/A '
#                                   'Previous Experience:\n'
#                                   '• 5+ Years professional experience in data '
#                                   'science application initiatives with '
#                                   'technical competencies as an engineer to '
#                                   'present the right data in user workflow to '
#                                   'make informed decisions\n'
#                                   '• Proven understanding of how to examine '
#                                   'data from multiple disparate sources to '
#                                   'present data science concepts in scalable '
#                                   'applications that drive data sets and '
#                                   'visualizations Core Capabilities:\n'
#                                   '• PHP Developer skills performant in '
#                                   'writing code, developing portals and '
#                                   'database optimization\n'
#                                   '• Competency in PHP web frameworks '
#                                   'including Yii, Laravel, and CodeIgniter\n'
#                                   '• Knowledge of Front End technologies '
#                                   'including CSS3, JavaScript, and HTML5.\n'
#                                   '• Understanding of object-oriented PHP '
#                                   'programming.\n'
#                                   '• Proficient with code versioning tools '
#                                   'including Git, Mercurial, CVS, and SVN.\n'
#                                   '• Familiarity with SQL/NoSQL databases. '
#                                   'Computer Skills:\n'
#                                   '• PHP web framework, object-oriented '
#                                   'programming and code development\n'
#                                   '• Front end technologies\n'
#                                   '• Familiarity with NLP technologies.\n'
#                                   '• Data governance software knowledge (eg, '
#                                   'Informatica, etc.)\n'
#                                   '• MS Office Word, Excel, Power Point, and '
#                                   'Outlook Travel:\n'
#                                   '• 25% Standard Core Workdays/Hours:\n'
#                                   '• Monday to Friday 8:00 AM - 5:00 PM',
#                    'detected_extensions': {'posted_at': '1 day ago',
#                                            'schedule_type': 'Full–time'},
#                    'extensions': ['1 day ago', 'Full–time'],
#                    'job_highlights': [{'items': ["Bachelor's degree in "
#                                                  'business analytics, computer '
#                                                  'science, engineering, '
#                                                  'accounting, finance, '
#                                                  'management information '
#                                                  'systems or another related '
#                                                  'field',
#                                                  'In lieu of degree, 10+ years '
#                                                  'of experience is required or '
#                                                  'the equivalent combination '
#                                                  'for education and experience '
#                                                  'Certifications/Licenses:',
#                                                  'Enter required licensure or '
#                                                  'N/A',
#                                                  'Enter required certification '
#                                                  'or N/A Previous Experience:',
#                                                  '5+ Years professional '
#                                                  'experience in data science '
#                                                  'application initiatives with '
#                                                  'technical competencies as an '
#                                                  'engineer to present the '
#                                                  'right data in user workflow '
#                                                  'to make informed decisions',
#                                                  'Proven understanding of how '
#                                                  'to examine data from '
#                                                  'multiple disparate sources '
#                                                  'to present data science '
#                                                  'concepts in scalable '
#                                                  'applications that drive data '
#                                                  'sets and visualizations Core '
#                                                  'Capabilities:',
#                                                  'PHP Developer skills '
#                                                  'performant in writing code, '
#                                                  'developing portals and '
#                                                  'database optimization',
#                                                  'Competency in PHP web '
#                                                  'frameworks including Yii, '
#                                                  'Laravel, and CodeIgniter',
#                                                  'Knowledge of Front End '
#                                                  'technologies including CSS3, '
#                                                  'JavaScript, and HTML5',
#                                                  'Understanding of '
#                                                  'object-oriented PHP '
#                                                  'programming',
#                                                  'Proficient with code '
#                                                  'versioning tools including '
#                                                  'Git, Mercurial, CVS, and SVN',
#                                                  'Familiarity with SQL/NoSQL '
#                                                  'databases',
#                                                  'PHP web framework, '
#                                                  'object-oriented programming '
#                                                  'and code development',
#                                                  'Familiarity with NLP '
#                                                  'technologies',
#                                                  'Data governance software '
#                                                  'knowledge (eg, Informatica, '
#                                                  'etc.)',
#                                                  'MS Office Word, Excel, Power '
#                                                  'Point, and Outlook Travel:',
#                                                  '25% Standard Core '
#                                                  'Workdays/Hours:'],
#                                        'title': 'Qualifications'},
#                                       {'items': ['The Data Scientist works '
#                                                  'cross functionally with the '
#                                                  "'trusted data' and DaaS "
#                                                  'teams to provide guidance as '
#                                                  'to how best to surface data '
#                                                  'science insights with an '
#                                                  'application',
#                                                  'As a Data Scientist (DSE) '
#                                                  'you will be engaged in '
#                                                  'analysis, code development, '
#                                                  'data integration and '
#                                                  'performance optimization '
#                                                  'initiatives to provide data '
#                                                  'science insights to users',
#                                                  'A Data Science Engineer '
#                                                  '(DSE) functions in both a '
#                                                  'consultative and technical '
#                                                  'capacity to deliver highly '
#                                                  'dimensional data intensive '
#                                                  'concepts',
#                                                  'To thrive on the FCS '
#                                                  'Informatics team the Data '
#                                                  'Scientist (DSE) must be an '
#                                                  'active contributor in a '
#                                                  'cross-functional '
#                                                  'entrepreneurial agile scrum '
#                                                  'environment to deliver in '
#                                                  'demand agile analytics',
#                                                  'Demonstrates working '
#                                                  'knowledge of all facets of '
#                                                  'role, relevant regulations, '
#                                                  'and organizational and '
#                                                  'departmental policies and '
#                                                  'procedures',
#                                                  'Performs other duties and '
#                                                  'projects as assigned',
#                                                  'Performs all duties in '
#                                                  'accordance with regulatory '
#                                                  'requirements and '
#                                                  'organizational policies and '
#                                                  'procedures',
#                                                  'Monday to Friday 8:00 AM - '
#                                                  '5:00 PM'],
#                                        'title': 'Responsibilities'}],
#                    'job_id': '...',
#                    'location': 'Tampa, FL, USA',
#                    'related_links': [{'link': 'https://www.google.com/search?hl=en&gl=uk&q=Florida+Cancer+Specialists&sa=X&ved=0ahUKEwicqYjpy7X9AhV7F1kFHYd-ABkQmJACCOYI',
#                                       'text': 'See web results for Florida '
#                                               'Cancer Specialists'}],
#                    'title': 'Informatics Data Science Engineer',
#                    'via': 'via JobServe'},
#                   {'company_name': 'Chubb INA Holdings Inc.',
#                    'description': 'Company Description\n'
#                                   '\n'
#                                   'Chubb is the world’s largest publicly '
#                                   'traded property and casualty insurer. With '
#                                   'operations in 54 countries, Chubb provides '
#                                   'commercial and personal property and '
#                                   'casualty insurance, personal accident and '
#                                   'supplemental health insurance, reinsurance '
#                                   'and life insurance to a diverse group of '
#                                   'clients. The company is distinguished by '
#                                   'its extensive product and service '
#                                   'offerings, broad... distribution '
#                                   'capabilities, exceptional financial '
#                                   'strength, underwriting excellence, superior '
#                                   'claims handling expertise and local '
#                                   'operations globally.\n'
#                                   '\n'
#                                   'Job Summary\n'
#                                   '\n'
#                                   'This position offers the opportunity to '
#                                   'leverage the entire spectrum of analytics '
#                                   'tools towards solving a wide variety of '
#                                   'business problems. The focus is on applying '
#                                   'a combination of industry standard '
#                                   'practices and innovative ideas using '
#                                   'structured and unstructured data from '
#                                   'multiple sources and applying AI, machine '
#                                   'learning and statistical techniques to '
#                                   'build, evaluate and implement models. Our '
#                                   'team focus’ on creating analytical '
#                                   'solutions that solve real world business '
#                                   'problems for all lines of business. '
#                                   'Analytics empowered technology platforms '
#                                   'are changing the way we operationalize '
#                                   'model outputs at Chubb. This role will work '
#                                   'closely with engineering teams to deploy '
#                                   'models as APIs into various cutting-edge '
#                                   'platforms. This is a great opportunity to '
#                                   'create analytic solutions for multiple '
#                                   'lines of business, deepening your insurance '
#                                   'product knowledge.\n'
#                                   '\n'
#                                   'Responsibilities\n'
#                                   '• Collaborate with business partners and '
#                                   'peers in the organization to understand and '
#                                   'scope the problem, gather business '
#                                   'requirements, and plan projects tasks and '
#                                   'timelines.\n'
#                                   '• Partner with Product Owners and other '
#                                   'data scientists to drive technical '
#                                   'execution of modeling projects (from '
#                                   'scoping, model development & review to '
#                                   'implementation).\n'
#                                   '• Execute all aspects of analytics '
#                                   'initiatives including exploratory data '
#                                   'analysis, machine learning model '
#                                   'development, model evaluation and benefit '
#                                   'estimation.\n'
#                                   '• Build modeling frameworks that can be '
#                                   'leveraged for multiple projects. High focus '
#                                   'on code reproducibility and creating '
#                                   'generalizable technology assets for '
#                                   'analytics teams.\n'
#                                   '• Create excellent working relationships '
#                                   'with business partners across the Chubb '
#                                   'organization, IT and analytics peer '
#                                   'groups.\n'
#                                   '• Effectively communicate results in '
#                                   'written, oral and presentation formats.\n'
#                                   '• Monitor performance of models and report '
#                                   'findings to leadership.\n'
#                                   '\n'
#                                   'Qualifications\n'
#                                   '\n'
#                                   'Required Skills/Experience\n'
#                                   '• 5+ years analytics background with '
#                                   'programming experience in Python or R '
#                                   'required.\n'
# ...
#                                   'problems including unstructured data, '
#                                   'ontology development, and ML applications\n'
#                                   '• Evaluate new technologies and tools prior '
#                                   'to wider adoption\n'
#                                   '\n'
#                                   'Minimum Requirements\n'
#                                   '• A degree in a quantitative field such as '
#                                   'Statistics, Machine Learning, Mathematics, '
#                                   'Computer Science, Economics, Epidemiology '
#                                   'or any other related field (Master’s Degree '
#                                   'or higher preferred)\n'
#                                   '• 5+ years of industry experience in ML '
#                                   'and/or data science roles in healthcare\n'
#                                   '\n'
#                                   'Additional Critical Skills\n'
#                                   '• Proficient in big data technologies such '
#                                   'as Hadoop, or Spark\n'
#                                   '• Deep understanding of NLP tools and '
#                                   'frameworks such as Spark NLP, spaCy, '
#                                   'HuggingFace, Flair, NLTK, etc\n'
#                                   '• Deep understanding of various machine '
#                                   'learning/deep learning algorithms, '
#                                   'including supervised, unsupervised, and '
#                                   'reinforcement learning methods.\n'
#                                   '• Proficient in OCR technologies such as '
#                                   'Tesseract\n'
#                                   '• Development and ML experience in cloud '
#                                   'platforms such as Microsoft Azure\n'
#                                   '\n'
#                                   'At McKesson, we care about the well-being '
#                                   'of the patients and communities we serve, '
#                                   'and that starts with caring for our people. '
#                                   'That’s why we have a Total Rewards package '
#                                   'that includes comprehensive benefits to '
#                                   'support physical, mental, and financial '
#                                   'well-being. Our Total Rewards offerings '
#                                   'serve the different needs of our diverse '
#                                   'employee population and ensure they are the '
#                                   'healthiest versions of themselves. For more '
#                                   'information regarding benefits at McKesson, '
#                                   'please click here.\n'
#                                   '\n'
#                                   'As part of Total Rewards, we are proud to '
#                                   'offer a competitive compensation package at '
#                                   'McKesson. This is determined by several '
#                                   'factors, including performance, experience '
#                                   'and skills, equity, regular job market '
#                                   'evaluations, and geographical markets. In '
#                                   'addition to base pay, other compensation, '
#                                   'such as an annual bonus or long-term '
#                                   'incentive opportunities may be offered.\n'
#                                   '\n'
#                                   'Our Base Pay Range for this position\n'
#                                   '\n'
#                                   '$117,500 - $195,800\n'
#                                   '\n'
#                                   'McKesson is an Equal '
#                                   'Opportunity/Affirmative Action employer.\n'
#                                   '\n'
#                                   'All qualified applicants will receive '
#                                   'consideration for employment without regard '
#                                   'to race, color, religion, creed, sex, '
#                                   'sexual orientation, gender identity, '
#                                   'national origin, disability, or protected '
#                                   'Veteran status.Qualified applicants will '
#                                   'not be disqualified from consideration for '
#                                   'employment based upon criminal history.\n'
#                                   '\n'
#                                   'McKesson is committed to being an Equal '
#                                   'Employment Opportunity Employer and offers '
#                                   'opportunities to all job seekers including '
#                                   'job seekers with disabilities. If you need '
#                                   'a reasonable accommodation to assist with '
#                                   'your job search or application for '
#                                   'employment, please contact us by sending an '
#                                   'email to '
#                                   'Disability_Accommodation@McKesson.com. '
#                                   'Resumes or CVs submitted to this email box '
#                                   'will not be accepted.\n'
#                                   '\n'
#                                   'Current employees must apply through the '
#                                   'internal career site.\n'
#                                   '\n'
#                                   'Join us at McKesson',
#                    'detected_extensions': {'posted_at': '2 days ago',
#                                            'schedule_type': 'Full–time'},
#                    'extensions': ['2 days ago', 'Full–time'],
#                    'job_highlights': [{'items': ['5+ years of industry '
#                                                  'experience in ML and/or data '
#                                                  'science roles in healthcare',
#                                                  'Additional Critical Skills',
#                                                  'Proficient in big data '
#                                                  'technologies such as Hadoop, '
#                                                  'or Spark',
#                                                  'Deep understanding of NLP '
#                                                  'tools and frameworks such as '
#                                                  'Spark NLP, spaCy, '
#                                                  'HuggingFace, Flair, NLTK, '
#                                                  'etc',
#                                                  'Deep understanding of '
#                                                  'various machine '
#                                                  'learning/deep learning '
#                                                  'algorithms, including '
#                                                  'supervised, unsupervised, '
#                                                  'and reinforcement learning '
#                                                  'methods',
#                                                  'Proficient in OCR '
#                                                  'technologies such as '
#                                                  'Tesseract',
#                                                  'Development and ML '
#                                                  'experience in cloud '
#                                                  'platforms such as Microsoft '
#                                                  'Azure'],
#                                        'title': 'Qualifications'},
#                                       {'items': ['Collaborate with product '
#                                                  'management, product owners '
#                                                  'and engineering departments '
#                                                  'to understand business needs '
#                                                  'and devise solutions',
#                                                  'Work closely with analysts, '
#                                                  'data warehousing, and data '
#                                                  'engineering teams in '
#                                                  'creating big data '
#                                                  'applications through the '
#                                                  'utilization of structured '
#                                                  'and unstructured data, '
#                                                  'designing, and developing '
#                                                  'optimal data architectures, '
#                                                  'and experimenting on new ML '
#                                                  'techniques',
#                                                  'Communicate process, '
#                                                  'requirements, assumptions '
#                                                  'and caveats of advanced ML '
#                                                  'and NLP concepts and '
#                                                  'deliverables in laymen '
#                                                  'languages to non-technical '
#                                                  'business leaders',
#                                                  'Research and prototype '
#                                                  'NLP-based solutions by '
#                                                  'utilizing data sources such '
#                                                  'as genomics, medical '
#                                                  'imaging, and speech-to-text '
#                                                  'outputs from healthcare '
#                                                  'technologies such as '
#                                                  "Nuance's Dragon suite",
#                                                  'Develop ML NLP models from '
#                                                  'unstructured healthcare data '
#                                                  'such as provider notes, EMR '
#                                                  'attached documentation, etc',
#                                                  'Maintain and enhance Optical '
#                                                  'Character Recognition (OCR) '
#                                                  'support for running NLP on '
#                                                  'scanned healthcare documents',
#                                                  'Participate in the full '
#                                                  'lifecycle of end-to-end NLP '
#                                                  'and OCR solutions, from '
#                                                  'planning, designing, '
#                                                  'technical implementation, '
#                                                  'deployment, validation, '
#                                                  'support, and maintenance',
#                                                  'Handle data engineering '
#                                                  'tasks using Python, PySpark, '
#                                                  'and Pandas',
#                                                  'Make use of state-of-the-art '
#                                                  'NLP model architectures such '
#                                                  'as BERT (and derivatives '
#                                                  'like BioBERT, RoBERTa, '
#                                                  'etc.), BiLSTM, and XLNet in '
#                                                  'NLP pipelines',
#                                                  'Design, implement, deploy, '
#                                                  'and maintain deep learning '
#                                                  'and ML models using cloud '
#                                                  'technologies (e.g., Azure '
#                                                  'Databricks)',
#                                                  'Provide mentorship and '
#                                                  'guidance to junior team '
#                                                  'members in areas of '
#                                                  'technical and professional '
#                                                  'development',
#                                                  'Develop creative solutions '
#                                                  'for diverse problems '
#                                                  'including unstructured data, '
#                                                  'ontology development, and ML '
#                                                  'applications',
#                                                  'Evaluate new technologies '
#                                                  'and tools prior to wider '
#                                                  'adoption'],
#                                        'title': 'Responsibilities'},
#                                       {'items': ['As part of Total Rewards, we '
#                                                  'are proud to offer a '
#                                                  'competitive compensation '
#                                                  'package at McKesson',
#                                                  'In addition to base pay, '
#                                                  'other compensation, such as '
#                                                  'an annual bonus or long-term '
#                                                  'incentive opportunities may '
#                                                  'be offered',
#                                                  'Our Base Pay Range for this '
#                                                  'position',
#                                                  '$117,500 - $195,800'],
#                                        'title': 'Benefits'}],
#                    'job_id': '...',
#                    'location': 'Texas, USA',
#                    'related_links': [{'link': 'http://www.mckesson.com/',
#                                       'text': 'mckesson.com'},
#                                      {'link': 'https://www.google.com/search?hl=en&gl=uk&q=MCKESSON&sa=X&ved=0ahUKEwicqYjpy7X9AhV7F1kFHYd-ABkQmJACCNoM',
#                                       'text': 'See web results for MCKESSON'}],
#                    'title': 'Sr. Data Scientist (NLP)',
#                    'via': 'via Jobs At MCKESSON'}],
#  'search_metadata': {'created_at': '2023-02-27 11:25:37 UTC',
#                      'google_jobs_url': 'https://www.google.com/search?q=data+scientist&ibp=htl;jobs&hl=en&gl=uk',
#                      'id': '63fc93319c449d8973d9f59d',
#                      'json_endpoint': 'https://serpapi.com/searches/6f7f83676f1d5dc9/63fc93319c449d8973d9f59d.json',
#                      'processed_at': '2023-02-27 11:25:37 UTC',
#                      'raw_html_file': 'https://serpapi.com/searches/6f7f83676f1d5dc9/63fc93319c449d8973d9f59d.html',
#                      'status': 'Success',
#                      'total_time_taken': 2.61},
#  'search_parameters': {'engine': 'google_jobs',
#                        'gl': 'uk',
#                        'google_domain': 'google.com',
#                        'hl': 'en',
#                        'q': 'data scientist'}}
